# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from openfast_toolbox.io import FASTOutputFile

# %%
outb_file = 'VolturnUS-15MW_Taut_1000m_hybrid_uncoupled.outb'

# %%
iteration = slice(-2000, -1, 50)

# %%
def organize_variables(df):
    vars = dict(
    time = df['Time_[s]'][iteration],
    wave_elev = df['Wave1Elev_[m]'][iteration],

    # l1px = df['BODY1PX_[m]'][iteration],
    # l1py = df['BODY1PY_[m]'][iteration],
    # l1pz = df['BODY1PZ_[m]'][iteration],
    # l1vx = df['BODY1VX_[m/s]'][iteration],
    # l1vy = df['BODY1VY_[m/s]'][iteration],
    # l1vz = df['BODY1VZ_[m/s]'][iteration],
    # l1fx = df['LINE2N50FX_[N]'][iteration],
    # l1fy = df['LINE2N50FY_[N]'][iteration],
    # l1fz = df['LINE2N50FZ_[N]'][iteration],

    # l2px = df['BODY2PX_[m]'][iteration],
    # l2py = df['BODY2PY_[m]'][iteration],
    # l2pz = df['BODY2PZ_[m]'][iteration],
    # l2vx = df['BODY2VX_[m/s]'][iteration],
    # l2vy = df['BODY2VY_[m/s]'][iteration],
    # l2vz = df['BODY2VZ_[m/s]'][iteration],
    # l2fx = df['LINE4N50FX_[N]'][iteration],
    # l2fy = df['LINE4N50FY_[N]'][iteration],
    # l2fz = df['LINE4N50FZ_[N]'][iteration],

    # l3px = df['BODY3PX_[m]'][iteration],
    # l3py = df['BODY3PY_[m]'][iteration],
    # l3pz = df['BODY3PZ_[m]'][iteration],
    # l3vx = df['BODY3VX_[m/s]'][iteration],
    # l3vy = df['BODY3VY_[m/s]'][iteration],
    # l3vz = df['BODY3VZ_[m/s]'][iteration],
    # l3fx = df['LINE6N50FX_[N]'][iteration],
    # l3fy = df['LINE6N50FY_[N]'][iteration],
    # l3fz = df['LINE6N50FZ_[N]'][iteration]
    l1fx = 
    l1fy = 
    
    )
    
    return pd.DataFrame.from_dict(vars)

# %%
df = FASTOutputFile(outb_file).toDataFrame()
data = organize_variables(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 df = FASTOutputFile(outb_file).toDataFrame()
# ----> 2 data = organize_variables(df)
#
# NameError: name 'organize_variables' is not defined

# %%
df['_[N]']
# Out:
#        Time_[s]  Wind1VelX_[m/s]  Wind1VelY_[m/s]  Wind1VelZ_[m/s]  \
# 0        60.000             10.0              0.0              0.0
# 1        60.025             10.0              0.0              0.0
# 2        60.050             10.0              0.0              0.0
# 3        60.075             10.0              0.0              0.0
# 4        60.100             10.0              0.0              0.0
# ...         ...              ...              ...              ...
# 23996   659.900             10.0              0.0              0.0
# 23997   659.925             10.0              0.0              0.0
# 23998   659.950             10.0              0.0              0.0
# 23999   659.975             10.0              0.0              0.0
# 24000   660.000             10.0              0.0              0.0
#
#        Azimuth_[deg]  BldPitch1_[deg]  BldPitch2_[deg]  BldPitch3_[deg]  \
# 0          52.806660              1.0              1.0              1.0
# 1          54.740218              1.0              1.0              1.0
# 2          56.668282              1.0              1.0              1.0
# 3          58.601839              1.0              1.0              1.0
# 4          60.535397              1.0              1.0              1.0
# ...              ...              ...              ...              ...
# 23996     342.356881              1.0              1.0              1.0
# 23997     344.504668              1.0              1.0              1.0
# 23998     346.646961              1.0              1.0              1.0
# 23999     348.789255              1.0              1.0              1.0
# 24000     350.931549              1.0              1.0              1.0
#
#        GenSpeed_[rpm]  IPDefl1_[m]  ...  AB1N048AxInd_[-]  AB1N049AxInd_[-]  \
# 0           12.884276    -1.162771  ...          0.902060          0.864459
# 1           12.884227    -1.190093  ...          0.900341          0.862497
# 2           12.884471    -1.216098  ...          0.898487          0.860355
# 3           12.884495    -1.240591  ...          0.896821          0.858477
# 4           12.884835    -1.263572  ...          0.895696          0.857091
# ...               ...          ...  ...               ...               ...
# 23996       14.291156     0.197400  ...          0.842058          0.829130
# 23997       14.291399     0.156940  ...          0.842370          0.829413
# 23998       14.292056     0.115782  ...          0.845151          0.831806
# 23999       14.291910     0.073462  ...          0.844880          0.831512
# 24000       14.291740     0.030212  ...          0.847026          0.832625
#
#        AB1N050AxInd_[-]  Wave1Elev_[m]  FAIRTEN1_[N]  FAIRTEN2_[N]  \
# 0                   1.0      -0.530248  5.919324e+06  2.668428e+06
# 1                   1.0      -0.514462  5.920191e+06  2.668352e+06
# 2                   1.0      -0.498646  5.921034e+06  2.668285e+06
# 3                   1.0      -0.482860  5.921901e+06  2.668210e+06
# 4                   1.0      -0.467043  5.922744e+06  2.668140e+06
# ...                 ...            ...           ...           ...
# 23996               1.0       0.035676  6.314892e+06  2.573340e+06
# 23997               1.0       0.017152  6.314880e+06  2.573050e+06
# 23998               1.0      -0.001432  6.314855e+06  2.572777e+06
# 23999               1.0      -0.019955  6.314855e+06  2.572475e+06
# 24000               1.0      -0.038540  6.314843e+06  2.572213e+06
#
#        FAIRTEN3_[N]  ANCHTEN1_[N]  ANCHTEN2_[N]  ANCHTEN3_[N]
# 0      2.646566e+06  4.717705e+06  1.387786e+06  1.365444e+06
# 1      2.646454e+06  4.718803e+06  1.387853e+06  1.365461e+06
# 2      2.646346e+06  4.719889e+06  1.387923e+06  1.365485e+06
# 3      2.646228e+06  4.720975e+06  1.388002e+06  1.365516e+06
# 4      2.646116e+06  4.722049e+06  1.388084e+06  1.365557e+06
# ...             ...           ...           ...           ...
# 23996  2.532150e+06  5.113478e+06  1.320084e+06  1.277862e+06
# 23997  2.531870e+06  5.113503e+06  1.319546e+06  1.277344e+06
# 23998  2.531589e+06  5.113540e+06  1.319004e+06  1.276822e+06
# 23999  2.531302e+06  5.113578e+06  1.318459e+06  1.276298e+06
# 24000  2.531015e+06  5.113615e+06  1.317911e+06  1.275766e+06
#
# [24001 rows x 889 columns]

# %%
print(f'l1fx:  max={data['l1fx'].max()},  min={data['l1fx'].min()}')
print(f'l2fx:  max={data['l2fx'].max()},  min={data['l2fx'].min()}')
print(f'l3fx:  max={data['l3fx'].max()},  min={data['l3fx'].min()}')
